# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/camvid/codes.txt'),
#  PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/images'),
#  PosixPath('/root/.fastai/data/camvid/labels')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# **DATA**

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0016E5_08109.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f01440.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f02400.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/0001TP_009570_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0006R0_f03120_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/Seq05VD_f03900_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ..., 26, 26, 26],
#           [ 4,  4,  4,  ..., 26, 26, 26],
#           [ 4,  4,  4,  ..., 26, 26, 26],
#           ...,
#           [17, 17, 17,  ..., 17, 17, 17],
#           [17, 17, 17,  ..., 17, 17, 17],
#           [17, 17, 17,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# **DATASET**

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# **MODEL**

# %%
#since some of the pixels in mask are labelled 'void', we need to exclude those pixels for calculating accuracy
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:01<00:00, 83.5MB/s]

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.241032</td>
#       <td>1.417820</td>
#       <td>0.653891</td>
#       <td>03:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.304841</td>
#       <td>0.829371</td>
#       <td>0.797917</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.947673</td>
#       <td>0.696110</td>
#       <td>0.824418</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.753951</td>
#       <td>0.575062</td>
#       <td>0.846495</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.661884</td>
#       <td>0.526402</td>
#       <td>0.858751</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.382829</td>
#       <td>0.342436</td>
#       <td>0.898936</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.375442</td>
#       <td>0.336364</td>
#       <td>0.900959</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.366024</td>
#       <td>0.333448</td>
#       <td>0.901623</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.361050</td>
#       <td>0.325118</td>
#       <td>0.904974</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.356799</td>
#       <td>0.319311</td>
#       <td>0.908011</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-2')

# %%
learn.show_results(rows=3, figsize=(8,9))

# %% [markdown]
# **GO BIG**

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# this Learner object self-destroyed - it still exists, but no longer usable
# using bs=3, have 11103MB of GPU RAM free

# %%
#here size=size implies we are using original size of source image unlike before where we used half the size of source image to train the model
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2')

# %%
lr_find(learn)
learn.recorder.plot()

# %%
lr=1e-4

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.00% [1/10 14:38<2:11:49]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...
